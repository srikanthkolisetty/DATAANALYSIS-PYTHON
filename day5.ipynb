# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Robust Scaling
# * If our dataset contains more number of outliers then robust scaling is the best technique to remove the outliers.

# %%
# xi--Q2(x)
#-------------
# Q3(x)-Q1(x)
#Q1-->25% value
# Q2-->median
# Q3--->75% value

# %%
import pandas as pd
import numpy as np

# %%
file=pd.read_csv('https://raw.githubusercontent.com/nagamounika5/Datasets/master/Advertisement.csv')

# %%
file.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
file.drop(['Unnamed: 0'],inplace=True,axis=1)

# %%
file
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
from sklearn.preprocessing import RobustScaler

# %%
rs=RobustScaler()
rs
# Out:
# RobustScaler()

# %%
rs2=rs.fit_transform(file)  # applys the robust scalar formula to the data.


rs2
# Out:
# array([[ 5.56247837e-01,  5.61205273e-01,  1.34312210e+00,
#          1.30960854e+00],
#        [-7.28625822e-01,  6.17702448e-01,  5.98145286e-01,
#         -3.55871886e-01],
#        [-9.17618553e-01,  8.66290019e-01,  1.34621329e+00,
#         -5.12455516e-01],
#        [ 1.21149187e-02,  6.93032015e-01,  1.01236476e+00,
#          7.97153025e-01],
#        [ 2.14953271e-01, -4.55743879e-01,  1.00927357e+00,
#          0.00000000e+00],
#        [-9.76462444e-01,  9.79284369e-01,  1.52241113e+00,
#         -8.11387900e-01],
#        [-6.38629283e-01,  3.72881356e-01, -6.95517774e-02,
#         -1.56583630e-01],
#        [-2.04569055e-01, -1.24293785e-01, -4.37403400e-01,
#          4.27046263e-02],
#        [-9.77154725e-01, -7.83427495e-01, -7.65069552e-01,
#         -1.15302491e+00],
#        [ 3.46486674e-01, -7.64595104e-01, -1.40649150e-01,
#         -3.27402135e-01],
#        [-5.79093112e-01, -6.44067797e-01, -4.79134467e-02,
#         -6.12099644e-01],
# ...

# %%
rs2=pd.DataFrame(rs2,columns=file.columns)
rs2.head()
# Out:
#          TV     radio  newspaper     sales
# 0  0.556248  0.561205   1.343122  1.309609
# 1 -0.728626  0.617702   0.598145 -0.355872
# 2 -0.917619  0.866290   1.346213 -0.512456
# 3  0.012115  0.693032   1.012365  0.797153
# 4  0.214953 -0.455744   1.009274  0.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig,(axis1,axis2) =plt.subplots(ncols=2,figsize=(9,5))
sns.kdeplot(file['TV'],ax=axis1)
sns.kdeplot(file['radio'],ax=axis1)
sns.kdeplot(file['newspaper'],ax=axis1)
sns.kdeplot(file['sales'],ax=axis1)

sns.kdeplot(rs2['TV'],ax=axis2)
sns.kdeplot(rs2['radio'],ax=axis2)
sns.kdeplot(rs2['newspaper'],ax=axis2)
sns.kdeplot(rs2['sales'],ax=axis2)

# %%
file.quantile(0.25)
# Out:
# TV           74.375
# radio         9.975
# newspaper    12.750
# sales        10.375
# Name: 0.25, dtype: float64

# %%
file.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# ### Standard Scaler
# * Most commonly used scaling  tehnique.It  scales between 0 to  mean value

# %%
# xi-mean(x)
# ----------------
# std(x)

# %%
from sklearn.preprocessing import StandardScaler

# %%
s=StandardScaler()

# %%
s2=s.fit_transform(file)

# %%
s2=pd.DataFrame(s2,columns=file.columns)
s2
# Out:
#            TV     radio  newspaper     sales
# 0    0.969852  0.981522   1.778945  1.552053
# 1   -1.197376  1.082808   0.669579 -0.696046
# 2   -1.516155  1.528463   1.783549 -0.907406
# 3    0.052050  1.217855   1.286405  0.860330
# 4    0.394182 -0.841614   1.281802 -0.215683
# ..        ...       ...        ...       ...
# 195 -1.270941 -1.321031  -0.771217 -1.234053
# 196 -0.617035 -1.240003  -1.033598 -0.830548
# 197  0.349810 -0.942899  -1.111852 -0.234898
# 198  1.594565  1.265121   1.640850  2.205347
# 199  0.993206 -0.990165  -1.005979 -0.119610
#
# [200 rows x 4 columns]

# %%
fig,(axis1,axis2) =plt.subplots(ncols=2,figsize=(9,5))
sns.kdeplot(file['TV'],ax=axis1)
sns.kdeplot(file['radio'],ax=axis1)
sns.kdeplot(file['newspaper'],ax=axis1)
sns.kdeplot(file['sales'],ax=axis1)

sns.kdeplot(s2['TV'],ax=axis2)
sns.kdeplot(s2['radio'],ax=axis2)
sns.kdeplot(s2['newspaper'],ax=axis2)
sns.kdeplot(s2['sales'],ax=axis2)

# %%
file.boxplot()

# %%
rs2.boxplot()

# %%
s2.boxplot()
