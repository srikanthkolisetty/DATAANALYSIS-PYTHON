# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
file=pd.read_csv('https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Data%20Analysis/Advertising.csv')

# %%
file.head(5)
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %% [markdown]
# ### .isna() is about whether their is any null values or not .

# %%
file.isna()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0         False  False  False      False  False
# 1         False  False  False      False  False
# 2         False  False  False      False  False
# 3         False  False  False      False  False
# 4         False  False  False      False  False
# ..          ...    ...    ...        ...    ...
# 195       False  False  False      False  False
# 196       False  False  False      False  False
# 197       False  False  False      False  False
# 198       False  False  False      False  False
# 199       False  False  False      False  False
#
# [200 rows x 5 columns]

# %%
file.isna().sum()  # total sum i.e number of null values in each column.
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
file.isnull().sum()   # isna() and isnull() are same used to find null values.
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
file.isnull().sum().sum() # total sum of all column null values
# Out:
# 0

# %%
file.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
file['newspaper'][0]   # to access particular value
# Out:
# 69.2

# %%
file.iloc[0:1]   # loc -location based indexing.
                 # iloc -index based indexing.
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1

# %%
file.loc[0]
# Out:
# Unnamed: 0      1.0
# TV            230.1
# radio          37.8
# newspaper      69.2
# sales          22.1
# Name: 0, dtype: float64

# %%
file.loc[0][3]
# Out:
# 69.2

# %%
file.loc[0,'newspaper']
# Out:
# 69.2

# %% [markdown]
# ### To read table data method is read_table() i.e .tsv file

# %%
tab_data=pd.read_table('https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Data%20Analysis/chipotle.tsv.txt')

# %%
tab_data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
tab_data.isna()
# Out:
#       order_id  quantity  item_name  choice_description  item_price
# 0        False     False      False                True       False
# 1        False     False      False               False       False
# 2        False     False      False               False       False
# 3        False     False      False                True       False
# 4        False     False      False               False       False
# ...        ...       ...        ...                 ...         ...
# 4617     False     False      False               False       False
# 4618     False     False      False               False       False
# 4619     False     False      False               False       False
# 4620     False     False      False               False       False
# 4621     False     False      False               False       False
#
# [4622 rows x 5 columns]

# %%
tab_data.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
tab_data.isnull().sum().sum()  # total null values in the data
# Out:
# 1246

# %%
tab_data['choice_description'].head(10)
# Out:
# 0                                                  NaN
# 1                                         [Clementine]
# 2                                              [Apple]
# 3                                                  NaN
# 4    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5    [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 6                                                  NaN
# 7    [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 8    [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...
# 9    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...
# Name: choice_description, dtype: object

# %%
tab_data.shape
# Out:
# (4622, 5)

# %%
tab_data.drop('choice_description',axis=1,inplace=True
             )

# %%
tab_data
# Out:
#       order_id  quantity                              item_name item_price
# 0            1         1           Chips and Fresh Tomato Salsa     $2.39
# 1            1         1                                   Izze     $3.39
# 2            1         1                       Nantucket Nectar     $3.39
# 3            1         1  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4            2         2                           Chicken Bowl    $16.98
# ...        ...       ...                                    ...        ...
# 4617      1833         1                          Steak Burrito    $11.75
# 4618      1833         1                          Steak Burrito    $11.75
# 4619      1834         1                     Chicken Salad Bowl    $11.25
# 4620      1834         1                     Chicken Salad Bowl     $8.75
# 4621      1834         1                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 4 columns]

# %%
dia_data=pd.read_csv('https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Classification/diabetes.csv')

# %%
dia_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dia_data.Outcome.unique()  # how many unique value's are present in the particular column
# Out:
# array([1, 0], dtype=int64)

# %%
dia_data[dia_data['Outcome']==1].count()
# Out:
# Pregnancies                 268
# Glucose                     268
# BloodPressure               268
# SkinThickness               268
# Insulin                     268
# BMI                         268
# DiabetesPedigreeFunction    268
# Age                         268
# Outcome                     268
# dtype: int64

# %%
dia_data[dia_data['Outcome']==0].count()
# Out:
# Pregnancies                 500
# Glucose                     500
# BloodPressure               500
# SkinThickness               500
# Insulin                     500
# BMI                         500
# DiabetesPedigreeFunction    500
# Age                         500
# Outcome                     500
# dtype: int64

# %%
tab_data2=pd.read_table('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/chipotle.tsv')

# %%
tab_data2.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
tab_data3=pd.read_table('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user',sep='|') # this file has no extension i.e we can use any method read_csv or read_table

# %%
tab_data3.head()
# Out:
#    1  24  M  technician  85711
# 0  2  53  F       other  94043
# 1  3  23  M      writer  32067
# 2  4  24  M  technician  43537
# 3  5  33  F       other  15213
# 4  6  42  M   executive  98101

# %%
tab_data3=pd.read_table('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user',sep='|',header=None) # this file has no extension i.e we can use any method read_csv or read_table

# %%
tab_data3 # when header is None i.e indexes will be present in headers
# Out:
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# ..   ...  .. ..            ...    ...
# 938  939  26  F        student  33319
# 939  940  32  M  administrator  02215
# 940  941  20  M        student  97229
# 941  942  48  F      librarian  78209
# 942  943  22  M        student  77841
#
# [943 rows x 5 columns]

# %%
tab_data3[3].unique()  # to find distinct values in a particular column.
# Out:
# array(['technician', 'other', 'writer', 'executive', 'administrator',
#        'student', 'lawyer', 'educator', 'scientist', 'entertainment',
#        'programmer', 'librarian', 'homemaker', 'artist', 'engineer',
#        'marketing', 'none', 'healthcare', 'retired', 'salesman', 'doctor'],
#       dtype=object)

# %%
tab_data3[tab_data3[3]=='student']
# Out:
#        0   1  2        3      4
# 8      9  29  M  student  01002
# 29    30   7  M  student  55436
# 31    32  28  F  student  78741
# 32    33  23  M  student  27510
# 35    36  19  F  student  93117
# ..   ...  .. ..      ...    ...
# 927  928  21  M  student  55408
# 932  933  28  M  student  48105
# 938  939  26  F  student  33319
# 940  941  20  M  student  97229
# 942  943  22  M  student  77841
#
# [196 rows x 5 columns]

# %%
tab_data3[tab_data3[3]=='entertainment'].count()
# Out:
# 0    18
# 1    18
# 2    18
# 3    18
# 4    18
# dtype: int64

# %%
tab_data4=pd.read_csv('https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Classification/titanic.csv')

# %%
tab_data4.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
tab_data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       714 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   ticket    891 non-null    object
#  8   fare      891 non-null    float64
#  9   cabin     204 non-null    object
#  10  embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %% [markdown]
#  ## if we need to apply any dataset to the machine learning all the columns datatype must in int or float
#  * get_dummie
#  * label encoder
#  ##### These two methods are used to convert object type  to int or float type.

# %%
tab_data4.isna().sum()
# Out:
# survived      0
# pclass        0
# name          0
# sex           0
# age         177
# sibsp         0
# parch         0
# ticket        0
# fare          0
# cabin       687
# embarked      2
# dtype: int64

# %%
tab_data4['age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
tab_data4['age'].fillna(tab_data4['age'].mean(),inplace=True)

# %%
tab_data4.head(10)
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       sex        age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.000000      1      0         A/5 21171   7.2500   NaN        S
# ...

# %%
tab_data4.drop('cabin',axis=1,inplace=True)

# %%
tab_data4
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex        age  sibsp  parch            ticket     fare embarked
# ...

# %%
tab_data4.isna().sum()
# Out:
# survived    0
# pclass      0
# name        0
# sex         0
# age         0
# sibsp       0
# parch       0
# ticket      0
# fare        0
# embarked    2
# dtype: int64

# %%
tab_data4['embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
tab_data4['embarked'].fillna('S',inplace=True)

# %%
tab_data4.isnull().sum()
# Out:
# survived    0
# pclass      0
# name        0
# sex         0
# age         0
# sibsp       0
# parch       0
# ticket      0
# fare        0
# embarked    0
# dtype: int64

# %% [markdown]
# ## get_dummies() to get dummies

# %%
pd.get_dummies(tab_data4['sex'])

# %% [markdown]
# # LabelEncoder
#  * it sets some values by it's own ,we cannot pass particular values.

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()

# %%
tab_data4['sex']=lab.fit_transform(tab_data4['sex'])

# %%
tab_data4
# Out:
#      survived  pclass                                               name  sex  \
# 0           0       3                            Braund, Mr. Owen Harris    1
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2           1       3                             Heikkinen, Miss. Laina    0
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 4           0       3                           Allen, Mr. William Henry    1
# ..        ...     ...                                                ...  ...
# 886         0       2                              Montvila, Rev. Juozas    1
# 887         1       1                       Graham, Miss. Margaret Edith    0
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"    0
# 889         1       1                              Behr, Mr. Karl Howell    1
# 890         0       3                                Dooley, Mr. Patrick    1
#
# ...

# %%
tab_data4['embarked']=lab.fit_transform(tab_data4['embarked'])

# %%
tab_data4
# Out:
#      survived  pclass                                               name  sex  \
# 0           0       3                            Braund, Mr. Owen Harris    1
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2           1       3                             Heikkinen, Miss. Laina    0
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 4           0       3                           Allen, Mr. William Henry    1
# ..        ...     ...                                                ...  ...
# 886         0       2                              Montvila, Rev. Juozas    1
# 887         1       1                       Graham, Miss. Margaret Edith    0
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"    0
# 889         1       1                              Behr, Mr. Karl Howell    1
# 890         0       3                                Dooley, Mr. Patrick    1
#
# ...
